# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Normalization, InputLayer, Dense
from tensorflow.keras.losses import MeanSquaredError, Huber, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam, AdamW
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
url = "http://bit.ly/w-data"
df = pd.read_csv(url)
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# ## Data Inspection

# %%
df.shape
# Out:
# (25, 2)

# %%
df.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('no. of hours studied')  
plt.ylabel('Percentage Scored')  
plt.show()

# %% [markdown]
# ## Data Preperation

# %%
tensor_data = tf.constant(df)
tensor_data = tf.random.shuffle(tensor_data)

# %%
X = tensor_data[:,0:1]
y = tensor_data[:,1:2]
print(X.shape, y.shape)
# Out:
# (25, 1) (25, 1)

# %%
X_train = X[0:20]
y_train = y[0:20]

# %%
X_val = X[20:22]
y_val = y[20:22]

# %%
X_test = X[22:]
y_test = y[22:]

# %%
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (20, 1) (2, 1) (3, 1)

# %%
train_data = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_data = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_data = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
normalizer = Normalization()
normalizer.adapt(X_train)
normalizer(X)[:5]
# Out:
# <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
# array([[-0.52994347],
#        [-0.1359334 ],
#        [-0.9239536 ],
#        [-1.4755677 ],
#        [-0.41174048]], dtype=float32)>

# %%
model = tf.keras.Sequential([
        InputLayer(shape=(1,)),
        normalizer,
        Dense(64, activation="relu"),
        Dense(1)
])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 1)              │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 196 (788.00 B)
#  Trainable params: 193 (772.00 B)
#  Non-trainable params: 3 (16.00 B)

# %%
model.compile(
        optimizer=Adam(learning_rate = 0.1), 
        loss=MeanAbsoluteError(),
        metrics = [RootMeanSquaredError()])

# %%
history = model.fit(train_data,
                    validation_data = val_data,
                    epochs=100,
                    verbose=1)
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 33.8650 - root_mean_squared_error: 40.4548 - val_loss: 23.2038 - val_root_mean_squared_error: 24.3279
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5689 - root_mean_squared_error: 8.6473 - val_loss: 3.7126 - val_root_mean_squared_error: 3.7421
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0130 - root_mean_squared_error: 10.1518 - val_loss: 8.6786 - val_root_mean_squared_error: 8.7777
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7180 - root_mean_squared_error: 6.8151 - val_loss: 17.9001 - val_root_mean_squared_error: 18.1564
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7082 - root_mean_squared_error: 8.0618 - val_loss: 18.5236 - val_root_mean_squared_error: 19.4058
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0369 - root_mean_squared_error: 7.6564 - val_loss: 1.1282 - val_root_mean_squared_error: 1.1285
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6515 - root_mean_squared_error: 8.4581 - val_loss: 22.9396 - val_root_mean_squared_error: 23.5233
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2391 - root_mean_squared_error: 8.9032 - val_loss: 2.3448 - val_root_mean_squared_error: 3.3073
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1706 - root_mean_squared_error: 9.9192 - val_loss: 1.1308 - val_root_mean_squared_error: 1.1475
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2314 - root_mean_squared_error: 8.0446 - val_loss: 20.8813 - val_root_mean_squared_error: 21.3886
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3788 - root_mean_squared_error: 7.7187 - val_loss: 6.8012 - val_root_mean_squared_error: 7.5105
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7779 - root_mean_squared_error: 5.5978 - val_loss: 11.0207 - val_root_mean_squared_error: 11.1635
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2571 - root_mean_squared_error: 6.6537 - val_loss: 1.8504 - val_root_mean_squared_error: 2.5422
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5387 - root_mean_squared_error: 5.9458 - val_loss: 13.5014 - val_root_mean_squared_error: 13.8923
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8321 - root_mean_squared_error: 4.7128 - val_loss: 10.7171 - val_root_mean_squared_error: 11.0642
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4375 - root_mean_squared_error: 5.6805 - val_loss: 3.5984 - val_root_mean_squared_error: 4.2428
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3130 - root_mean_squared_error: 5.8949 - val_loss: 14.9050 - val_root_mean_squared_error: 15.3333
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5641 - root_mean_squared_error: 4.6094 - val_loss: 9.1004 - val_root_mean_squared_error: 9.4418
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3169 - root_mean_squared_error: 5.3735 - val_loss: 11.3512 - val_root_mean_squared_error: 11.9649
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1499 - root_mean_squared_error: 5.2123 - val_loss: 9.0923 - val_root_mean_squared_error: 9.1547
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2631 - root_mean_squared_error: 7.5632 - val_loss: 18.6897 - val_root_mean_squared_error: 19.8473
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2829 - root_mean_squared_error: 10.8289 - val_loss: 3.2007 - val_root_mean_squared_error: 3.2218
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1952 - root_mean_squared_error: 11.5595 - val_loss: 16.5651 - val_root_mean_squared_error: 16.9840
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2752 - root_mean_squared_error: 4.7948 - val_loss: 10.5524 - val_root_mean_squared_error: 10.8177
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0129 - root_mean_squared_error: 5.2640 - val_loss: 4.3242 - val_root_mean_squared_error: 4.7376
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8365 - root_mean_squared_error: 5.6897 - val_loss: 15.0110 - val_root_mean_squared_error: 15.3111
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7310 - root_mean_squared_error: 5.7145 - val_loss: 3.8299 - val_root_mean_squared_error: 4.5458
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0684 - root_mean_squared_error: 5.9928 - val_loss: 16.0468 - val_root_mean_squared_error: 16.3103
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8444 - root_mean_squared_error: 6.7375 - val_loss: 3.2869 - val_root_mean_squared_error: 4.2931
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4572 - root_mean_squared_error: 6.2283 - val_loss: 15.1704 - val_root_mean_squared_error: 15.5115
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8327 - root_mean_squared_error: 6.1053 - val_loss: 2.9652 - val_root_mean_squared_error: 3.5833
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9899 - root_mean_squared_error: 6.9016 - val_loss: 14.0388 - val_root_mean_squared_error: 14.4323
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8617 - root_mean_squared_error: 5.0327 - val_loss: 9.3521 - val_root_mean_squared_error: 10.0320
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8309 - root_mean_squared_error: 5.9079 - val_loss: 0.8291 - val_root_mean_squared_error: 0.8305
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0102 - root_mean_squared_error: 7.8621 - val_loss: 2.4292 - val_root_mean_squared_error: 2.7487
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2938 - root_mean_squared_error: 8.7351 - val_loss: 9.5178 - val_root_mean_squared_error: 9.8598
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8560 - root_mean_squared_error: 4.8677 - val_loss: 7.2068 - val_root_mean_squared_error: 7.8589
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7110 - root_mean_squared_error: 5.9592 - val_loss: 1.5567 - val_root_mean_squared_error: 1.5568
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4340 - root_mean_squared_error: 7.0071 - val_loss: 1.9773 - val_root_mean_squared_error: 2.1196
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4301 - root_mean_squared_error: 5.8746 - val_loss: 16.3533 - val_root_mean_squared_error: 16.9147
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7480 - root_mean_squared_error: 5.8408 - val_loss: 1.0170 - val_root_mean_squared_error: 1.1640
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2499 - root_mean_squared_error: 6.7108 - val_loss: 2.5951 - val_root_mean_squared_error: 3.4167
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3706 - root_mean_squared_error: 6.3995 - val_loss: 11.2270 - val_root_mean_squared_error: 11.4735
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9594 - root_mean_squared_error: 5.1242 - val_loss: 3.0329 - val_root_mean_squared_error: 3.4170
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6468 - root_mean_squared_error: 5.4320 - val_loss: 11.7833 - val_root_mean_squared_error: 12.0566
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9426 - root_mean_squared_error: 4.6878 - val_loss: 9.0838 - val_root_mean_squared_error: 9.4081
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0351 - root_mean_squared_error: 5.3989 - val_loss: 10.6981 - val_root_mean_squared_error: 11.2345
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3715 - root_mean_squared_error: 5.7009 - val_loss: 0.2546 - val_root_mean_squared_error: 0.2936
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2792 - root_mean_squared_error: 7.6744 - val_loss: 3.6951 - val_root_mean_squared_error: 4.3252
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1256 - root_mean_squared_error: 5.5137 - val_loss: 10.4866 - val_root_mean_squared_error: 10.7305
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7325 - root_mean_squared_error: 4.6985 - val_loss: 6.2739 - val_root_mean_squared_error: 6.6599
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1925 - root_mean_squared_error: 5.4035 - val_loss: 1.5812 - val_root_mean_squared_error: 1.7228
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8495 - root_mean_squared_error: 6.4875 - val_loss: 14.9754 - val_root_mean_squared_error: 15.5130
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7135 - root_mean_squared_error: 5.7420 - val_loss: 2.4048 - val_root_mean_squared_error: 2.6368
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2232 - root_mean_squared_error: 5.5329 - val_loss: 14.9117 - val_root_mean_squared_error: 15.3797
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8721 - root_mean_squared_error: 5.0238 - val_loss: 3.0331 - val_root_mean_squared_error: 3.3936
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8527 - root_mean_squared_error: 5.6308 - val_loss: 10.3872 - val_root_mean_squared_error: 10.7752
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5489 - root_mean_squared_error: 4.7544 - val_loss: 4.5290 - val_root_mean_squared_error: 4.7971
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2119 - root_mean_squared_error: 4.9137 - val_loss: 9.1398 - val_root_mean_squared_error: 9.4193
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4877 - root_mean_squared_error: 4.5138 - val_loss: 4.6451 - val_root_mean_squared_error: 5.0067
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4804 - root_mean_squared_error: 5.1881 - val_loss: 12.2538 - val_root_mean_squared_error: 12.5858
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5392 - root_mean_squared_error: 4.5449 - val_loss: 7.5995 - val_root_mean_squared_error: 8.2849
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6011 - root_mean_squared_error: 5.5726 - val_loss: 2.4471 - val_root_mean_squared_error: 2.5875
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7095 - root_mean_squared_error: 7.2033 - val_loss: 8.1458 - val_root_mean_squared_error: 8.5300
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6791 - root_mean_squared_error: 4.7570 - val_loss: 13.3362 - val_root_mean_squared_error: 13.6130
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0881 - root_mean_squared_error: 4.7485 - val_loss: 4.6952 - val_root_mean_squared_error: 5.1859
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3777 - root_mean_squared_error: 5.1046 - val_loss: 12.8379 - val_root_mean_squared_error: 13.0936
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4649 - root_mean_squared_error: 5.2424 - val_loss: 3.1071 - val_root_mean_squared_error: 4.1406
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1528 - root_mean_squared_error: 5.9827 - val_loss: 12.8979 - val_root_mean_squared_error: 13.1288
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2496 - root_mean_squared_error: 5.9758 - val_loss: 3.0201 - val_root_mean_squared_error: 3.9219
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6331 - root_mean_squared_error: 6.7666 - val_loss: 14.4530 - val_root_mean_squared_error: 14.7884
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4125 - root_mean_squared_error: 5.3511 - val_loss: 5.2574 - val_root_mean_squared_error: 6.0186
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8332 - root_mean_squared_error: 5.6103 - val_loss: 13.3130 - val_root_mean_squared_error: 13.7440
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8540 - root_mean_squared_error: 5.1800 - val_loss: 1.2811 - val_root_mean_squared_error: 1.8026
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9493 - root_mean_squared_error: 5.5315 - val_loss: 10.2904 - val_root_mean_squared_error: 10.5556
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4391 - root_mean_squared_error: 4.4252 - val_loss: 7.7585 - val_root_mean_squared_error: 8.0719
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1016 - root_mean_squared_error: 5.0399 - val_loss: 9.2844 - val_root_mean_squared_error: 9.8074
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1164 - root_mean_squared_error: 5.1229 - val_loss: 1.0777 - val_root_mean_squared_error: 1.1422
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6517 - root_mean_squared_error: 5.9258 - val_loss: 4.9825 - val_root_mean_squared_error: 5.2346
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0992 - root_mean_squared_error: 5.2625 - val_loss: 5.6124 - val_root_mean_squared_error: 5.6651
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4314 - root_mean_squared_error: 5.1194 - val_loss: 14.2297 - val_root_mean_squared_error: 14.5835
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9923 - root_mean_squared_error: 5.5237 - val_loss: 1.6875 - val_root_mean_squared_error: 2.2362
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8950 - root_mean_squared_error: 5.7633 - val_loss: 2.3858 - val_root_mean_squared_error: 2.4710
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4316 - root_mean_squared_error: 5.8896 - val_loss: 17.7921 - val_root_mean_squared_error: 18.3042
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2697 - root_mean_squared_error: 6.2648 - val_loss: 1.7056 - val_root_mean_squared_error: 2.4038
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9127 - root_mean_squared_error: 7.2796 - val_loss: 15.6212 - val_root_mean_squared_error: 16.0106
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4724 - root_mean_squared_error: 5.6823 - val_loss: 2.0315 - val_root_mean_squared_error: 2.0777
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5306 - root_mean_squared_error: 6.1196 - val_loss: 9.8592 - val_root_mean_squared_error: 10.1946
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9665 - root_mean_squared_error: 4.9570 - val_loss: 4.7474 - val_root_mean_squared_error: 5.6282
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0611 - root_mean_squared_error: 5.8433 - val_loss: 2.8095 - val_root_mean_squared_error: 3.0418
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 4.8813 - root_mean_squared_error: 6.1222 - val_loss: 16.5685 - val_root_mean_squared_error: 17.0645
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5487 - root_mean_squared_error: 5.8032 - val_loss: 1.9164 - val_root_mean_squared_error: 2.2462
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7200 - root_mean_squared_error: 6.5637 - val_loss: 13.4269 - val_root_mean_squared_error: 13.7838
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8722 - root_mean_squared_error: 5.0014 - val_loss: 5.3564 - val_root_mean_squared_error: 6.2709
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0380 - root_mean_squared_error: 5.9266 - val_loss: 2.1341 - val_root_mean_squared_error: 2.9358
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0536 - root_mean_squared_error: 6.0221 - val_loss: 17.1994 - val_root_mean_squared_error: 17.8088
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0972 - root_mean_squared_error: 6.4982 - val_loss: 2.8104 - val_root_mean_squared_error: 3.8728
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2733 - root_mean_squared_error: 6.0174 - val_loss: 8.0744 - val_root_mean_squared_error: 8.3093
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2088 - root_mean_squared_error: 5.2306 - val_loss: 3.1916 - val_root_mean_squared_error: 3.8035
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7661 - root_mean_squared_error: 5.2243 - val_loss: 10.2444 - val_root_mean_squared_error: 10.5676

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["train", "val_loss"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(history.history["root_mean_squared_error"])
plt.plot(history.history["val_root_mean_squared_error"])
plt.title("model performance (rmse)")
plt.ylabel("RMSE")
plt.xlabel("Epoch")
plt.legend(["train", "val"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Model Evaluation and testing

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.2299 - root_mean_squared_error: 6.5073
# [5.229915142059326, 6.50730037689209]

# %%
model.predict(tf.expand_dims(X_test[0], axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# array([[69.193405]], dtype=float32)

# %%
y_true = list(y_test[:, 0])

# %%
y_pred = list(model.predict(X_test)[:,0])
print(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [69.193405, 18.113173, 50.390488]

# %%
print(y_pred)
# Out:
# [69.193405, 18.113173, 50.390488]

# %%
print(y_test)
# Out:
# tf.Tensor(
# [[69.]
#  [24.]
#  [60.]], shape=(3, 1), dtype=float64)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_true, y_pred, color='blue', label='Predicted vs True', alpha=0.6)
plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], color='red', linestyle='--', label='Perfect Fit')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('True vs Predicted Values')
plt.legend()
plt.show()

# %% [markdown]
# ## prediction if a student studied for 9.5hrs

# %%
input_value = np.array([[9.5]])  # Note the double brackets to match (1,)

# Predict
prediction = model.predict(input_value)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[89.9742]]
